# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from utility import get_sample_df

# %%
algo = "prediction_nn"
df = get_sample_df(path = "/results/{}/realKnownCause/".format(algo), file = "{}_rogue_agent_key_hold.csv".format(algo))
probation_period = 750 if(len(df)>=5000) else int(0.15*len(df))

# %%
plt.plot(df.anomaly_score.values[probation_period:])

# %%
time_ser = df.anomaly_score.values
mu,std = norm.fit(time_ser)
plt.hist(time_ser, bins=20, density=True, alpha=0.6, color='g')
xmin, xmax = plt.xlim()

# %%
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt


# Generate some data for this demonstration.
data = norm.rvs(10.0, 2.5, size=500)

# Fit a normal distribution to the data:
mu, std = norm.fit(data)

# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='g')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()
